# %%
import sklearn
import os 
import pandas as pd
import numpy as np

# %% [markdown]
# **IMPORTING FILES**

# %%
#reads files and creates list
def filereader(path):
    list_of_comments = []
    all_files = os.listdir(path)
    for folder in all_files:
        files = os.listdir(path+folder)
        for file in files:
            pathname = path+folder+'\\'+file
            file = open(pathname, 'r')
            list_of_comments.append(file.readline())
    return list_of_comments

# %%
# Ott et. al (2011) - MTurk Hotel dataset
neg_pol_truthful = filereader("C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\")
neg_pol_deceptive = filereader("C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\deceptive_from_MTurk\\")
pos_pol_truthful = filereader("C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\truthful_from_TripAdvisor\\")
pos_pol_deceptive = filereader("C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\")
# Out:
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_1.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_1.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_10.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_10.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_11.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_11.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_12.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_12.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_13.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_13.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_14.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_14.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_15.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_15.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_16.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_16.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_17.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_17.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_18.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_18.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_19.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_19.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_2.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_2.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_20.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_20.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_3.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_3.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_4.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_4.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_5.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_5.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_6.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_6.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_7.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_7.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_8.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_8.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_9.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_hilton_9.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_1.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_1.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_10.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_10.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_11.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_11.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_12.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_12.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_13.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_13.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_14.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_14.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_15.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_15.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_16.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_16.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_17.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_17.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_18.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_18.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_19.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_19.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_2.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_2.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_20.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_20.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_3.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_3.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_4.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_4.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_5.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_5.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_6.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_6.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_7.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_7.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_8.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_8.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_9.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_james_9.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_1.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_1.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_10.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_10.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_11.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_11.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_12.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_12.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_13.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_13.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_14.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_14.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_15.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_15.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_16.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_16.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_17.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_17.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_18.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_18.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_19.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_19.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_2.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_2.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_20.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_20.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_3.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_3.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_4.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_4.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_5.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_5.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_6.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_6.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_7.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_7.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_8.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_8.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_9.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_monaco_9.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_1.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_1.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_10.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_10.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_11.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_11.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_12.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_12.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_13.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_13.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_14.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_14.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_15.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_15.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_16.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_16.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_17.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_17.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_18.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_18.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_19.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_19.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_2.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_2.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_20.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_20.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_3.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_3.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_4.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_4.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_5.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_5.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_6.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_6.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_7.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_7.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_8.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_8.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_9.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold1\\t_sofitel_9.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold2\\t_affinia_1.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold2\\t_affinia_1.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold2\\t_affinia_10.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\negative_polarity\\truthful_from_Web\\fold2\\t
txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_7.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_7.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_8.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_8.txt' mode='r' encoding='cp1252'>
# Exception ignored in: <_io.FileIO name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_9.txt' mode='rb' closefd=True>
# ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\alexa\\Desktop\\op_spam_dataset\\positive_polarity\\deceptive_from_MTurk\\fold5\\d_palmer_9.txt' mode='r' encoding='cp1252'>

# %%
# Mukherjee et. al (2013) - Yelp Hotel dataset
df = pd.read_csv(r'C:\Users\alexa\Desktop\YelpReviews.csv')
df = df.sample(frac=1).reset_index(drop=True) #shuffle and reset index

#creating deceptive lists
deceptive = df[df['flagged']=='Y']
pos_dec = deceptive[deceptive['rating'] > 2]
neg_dec = deceptive[deceptive['rating'] < 3] 
pos_pol_deceptive = [str(review) for review in pos_dec['reviewContent']]
pos_pol_deceptive = [review.replace(u'\xa0', u' ') for review in pos_pol_deceptive]
neg_pol_deceptive = [str(review) for review in neg_dec['reviewContent']]
neg_pol_deceptive = [review.replace(u'\xa0', u' ') for review in neg_pol_deceptive]

# creating truthful lists
truthful = df[df['flagged']=='N'][:780] #shuffled before, so random selection for balanced dataset
pos_tru = truthful[truthful['rating'] > 2]
neg_tru = truthful[truthful['rating'] < 3]
pos_pol_truthful = [str(review) for review in pos_tru['reviewContent']]
pos_pol_truthful = [review.replace(u'\xa0', u' ') for review in pos_pol_truthful]
neg_pol_truthful = [str(review) for review in neg_tru['reviewContent']]
neg_pol_truthful = [review.replace(u'\xa0', u' ') for review in neg_pol_truthful]

# %%
# Rayana (2015) - Yelp Restaurant dataset

#importing content
file = open("reviewContent", "rb")
content = file.readlines()
newlist = []
for file in content[:5000]:
    decoded = file.decode("utf-8")
    splitted = decoded.split('\t')
    splitted[3].replace(u'\xa0', u' ')
    newlist += [splitted]
    
#importing labels
file2 = open("metadata", "rb")
content2 = file2.readlines()
newlist2 = []
for file in content2[:5000]:
    decoded = file.decode("utf-8")
    splitted = decoded.split('\t')
    newlist2 += [splitted]

#creating dataframe
df = pd.DataFrame(newlist)
df = df.drop([0,1,2], 1)
df.columns = ['content']

df2 = pd.DataFrame(newlist2)
df2 = df2.drop([0,1,4], 1)
df2.columns = ['rating', 'label']
df = df.join(df2)
df = df.sample(frac=1).reset_index(drop=True) #shuffle and reset index
df = df.astype({"rating": float})

#creating deceptive lists
deceptive = df.loc[df['label'] == '-1'][:800] #shuffles before, so random
pos_dec = deceptive[deceptive['rating'] > 2]
neg_dec = deceptive[deceptive['rating'] < 3] 
pos_pol_deceptive = [str(review) for review in pos_dec['content']]
neg_pol_deceptive = [str(review) for review in neg_dec['content']]

# creating truthful lists
truthful = df.loc[df['label'] == '1'][:800]
pos_tru = truthful[truthful['rating'] > 2]
neg_tru = truthful[truthful['rating'] < 3]
pos_pol_truthful = [str(review) for review in pos_tru['content']]
neg_pol_truthful = [str(review) for review in neg_tru['content']]

# %% [markdown]
# **PREPROCESSING**

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from random import shuffle

# %%
def preprocessing(text, pos_tags=False):
    # tokenize into words
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]   

    # remove stopwords
    stop = stopwords.words('english')
    tokens = [token for token in tokens if token not in stop]

    # remove words less than three characters
    tokens = [word for word in tokens if len(word) >= 3]

    # remove capitalization
    tokens = [word.lower() for word in tokens]

    # lemmatizing
    lmtzr = WordNetLemmatizer()
    tokens = [lmtzr.lemmatize(word) for word in tokens]

    # includes POS_tags
    if pos_tags:
        tokens = nltk.pos_tag(tokens)
        tokens = ['_'.join(t) for t in tokens]
    
    preprocessed_text= ' '.join(tokens)

    return preprocessed_text 

def preprocesser(list_of_texts): # turning lists into preprocessed lists
    new = []
    for item in list_of_texts:
        new += [preprocessing(item)]
    return new

# %%
# labelling data: 0 for truthful, 1 for deceptive
corpus_neg_truthful = [(r,0) for r in preprocesser(neg_pol_truthful)]
corpus_neg_deceptive = [(r,1) for r in preprocesser(neg_pol_deceptive)]
corpus_pos_truthful = [(r,0) for r in preprocesser(pos_pol_truthful)]
corpus_pos_deceptive = [(r,1) for r in preprocesser(pos_pol_deceptive)]

# %%
# shuffle data instances
from random import shuffle
corpus = corpus_neg_truthful+corpus_neg_deceptive+corpus_pos_truthful+corpus_pos_deceptive
shuffle(corpus)
reviews = [r for r,l in corpus]
labels_y = [l for r,l in corpus]

# %% [markdown]
# **TSVM**

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from self_learning.methods.scikitTSVM import *
from self_learning.methods.qns3vm import *
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score, cross_validate, KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
from statistics import mean, stdev
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# <ipython-input-24-344be9ee7712> in <module>
#       4 from sklearn.svm import SVC
#       5 from sklearn.naive_bayes import MultinomialNB
# ----> 6 from sklearn.ensemble import RandomForestClassifier
#       7 from sklearn.feature_selection import chi2
#       8 from sklearn.model_selection import cross_val_score, cross_validate, KFold
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\__init__.py in <module>
#       6
#       7 from ._base import BaseEnsemble
# ----> 8 from ._forest import RandomForestClassifier
#       9 from ._forest import RandomForestRegressor
#      10 from ._forest import RandomTreesEmbedding
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in <module>
#      54 from ..metrics import r2_score
#      55 from ..preprocessing import OneHotEncoder
# ---> 56 from ..tree import (DecisionTreeClassifier, DecisionTreeRegressor,
#      57                     ExtraTreeClassifier, ExtraTreeRegressor)
#      58 from ..tree._tree import DTYPE, DOUBLE
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\__init__.py in <module>
#       4 """
#       5
# ----> 6 from ._classes import BaseDecisionTree
#       7 from ._classes import DecisionTreeClassifier
#       8 from ._classes import DecisionTreeRegressor
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in <module>
#      39 from ..utils.validation import _deprecate_positional_args
#      40
# ---> 41 from ._criterion import Criterion
#      42 from ._splitter import Splitter
#      43 from ._tree import DepthFirstTreeBuilder
#
# sklearn\tree\_criterion.pyx in init sklearn.tree._criterion()
#
# RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
# from sklearn.svm import SVC
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import chi2
# from sklearn.model_selection import cross_val_score, cross_validate, KFold
# from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
# from statistics import mean, stdev
# from datetime import datetime
from sklearn.feature_selection import chi2
# Out:
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# <ipython-input-15-75b6f8369ed5> in <module>
#       7 # from statistics import mean, stdev
#       8 # from datetime import datetime
# ----> 9 from sklearn.feature_selection import chi2
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\__init__.py in <module>
#      23 from ._from_model import SelectFromModel
#      24
# ---> 25 from ._mutual_info import mutual_info_regression, mutual_info_classif
#      26
#      27 from ._base import SelectorMixin
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in <module>
#       7
#       8 from ..metrics.cluster import mutual_info_score
# ----> 9 from ..neighbors import NearestNeighbors
#      10 from ..preprocessing import scale
#      11 from ..utils import check_random_state
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\__init__.py in <module>
#       4 """
#       5
# ----> 6 from ._ball_tree import BallTree
#       7 from ._kd_tree import KDTree
#       8 from ._dist_metrics import DistanceMetric
#
# sklearn\neighbors\_ball_tree.pyx in init sklearn.neighbors._ball_tree()
#
# RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
def main_TSVM_CV(ratio, vectorizertype, ngram, nsplits):
   
    """
    Main function with cross-validation included
    Parameters:
        ratio (number of labels to remove) = float (0.80 / 0.90 / 0.95)
        vectorizertype (word counts or TF-IDF values) = CountVectorizer / TfidfVectorizer
        ngram (word pairs) = int (1=unigram, 2=bigram)
        nsplits (cross validation splits) = int (number of splits)
    
    """
    TSVM_results = {'accuracy':[], '1':{'precision':[], 'recall':[], 'f1-score':[]}}

    
    # creating dataframe 
    vectorizer = vectorizertype(min_df=2, max_df=0.5, ngram_range=(1,ngram))
    X = vectorizer.fit_transform(reviews)
    DF = pd.DataFrame(X.todense(),columns=vectorizer.get_feature_names())
    DF['Y'] = labels_y
    X = DF.drop('Y', axis=1)
    y = DF['Y']
    
    # feature selection
    def chi_square(X, y): 
        F, pval = chi2(X, y) 
        return F
    def feature_ranking(F):
        idx = np.argsort(F)
        return idx[::-1]
    df = pd.DataFrame(feature_ranking(chi_square(X,y)))
    df.columns = ['column_numbers']
    clms_toselect = df['column_numbers'].head(1000)
    a = [DF.columns[i] for i in clms_toselect]
    X = DF[a]
    X = X.to_numpy()
    
    # KFold crossvalidation
    kf = KFold(n_splits=nsplits, shuffle=False)
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        # removing labels    
        rng = np.random.RandomState(42) 
        random_unlabeled_points = rng.rand(len(y_train)) < ratio
        labels = np.copy(y_train)
        labels[random_unlabeled_points] = -1
        y_train = labels

        # train model
        tsvm_model = SKTSVM(kernel='rbf',C=0.0002, gamma=20) #WRAPS QN3SVM
        tsvm_model.fit(X_train, y_train)
        
        # evaluate model
        y_pred = tsvm_model.predict(X_test)

        report = classification_report(y_test,y_pred, output_dict=True)
        TSVM_results['accuracy'] += [report['accuracy']]
        TSVM_results['1']['precision'] += [report['1']['precision']]
        TSVM_results['1']['recall'] += [report['1']['recall']]
        TSVM_results['1']['f1-score'] += [report['1']['f1-score']]
        
    with open('TSVM_results.txt', 'a') as file:
        file.write('___ratio:' + str(ratio) + '|ngram:' + str(ngram) + '|vectorizer:'+ str(vectorizertype) + '___\n')
        file.write('accuracy: ' + str(round(mean(TSVM_results['accuracy']),2)) + '\n')
        file.write('stddev: ' + str(stdev(TSVM_results['accuracy'])) + '\n')
        file.write('precision: ' + str(round(mean(TSVM_results['1']['precision']),2)) + '\n')
        file.write('recall: ' + str(round(mean(TSVM_results['1']['recall']),2)) + '\n')
        file.write('F1 :' + str(round(mean(TSVM_results['1']['f1-score']),2)) + '\n\n')
        obj = datetime.now()
        file.write(str(obj) + '\n\n\n')

# %%
main_TSVM_CV(ratio=0.80, vectorizertype=CountVectorizer, ngram=1, nsplits=5)
# Out:
# ---------------------------------------------------------------------------
# PendingDeprecationWarning                 Traceback (most recent call last)
# <ipython-input-20-0d1a9b9f81fc> in <module>
# ----> 1 main_TSVM_CV(ratio=0.80, vectorizertype=CountVectorizer, ngram=1, nsplits=5)
#
# <ipython-input-19-b13a07a7ba5f> in main_TSVM_CV(ratio, vectorizertype, ngram, nsplits)
#      50         # train model
#      51         tsvm_model = SKTSVM(kernel='rbf',C=0.0002, gamma=20) #WRAPS QN3SVM
# ---> 52         tsvm_model.fit(X_train, y_train)
#      53
#      54         # evaluate model
#
# ~\Desktop\self_learning\methods\scikitTSVM.py in fit(self, X, y)
#      77             self.model = QN_S3VM(labeledX, labeledy, unlabeledX, self.random_generator, lam=self.C, lamU=self.lamU)
#      78
# ---> 79         self.model.train()
#      80
#      81         # probabilities by Platt scaling
#
# ~\Desktop\qns3vm.py in train(self)
#     140         The computed partition for the unlabeled patterns.
#     141         """
# --> 142         return self.__model.train()
#     143
#     144     def getPredictions(self, X, real_valued=False):
#
# ~\Desktop\qns3vm.py in train(self)
#     237         The computed partition for the unlabeled patterns.
#     238         """
# --> 239         indi_opt = self.__optimize()
#     240         self.__recomputeModel(indi_opt)
#     241         predictions = self.__getTrainingPredictions(self.__X)
#
# ~\Desktop\qns3vm.py in __optimize(self)
#     351         logging.debug("Starting optimization with BFGS ...")
#     352         self.__needed_function_calls = 0
# --> 353         self.__initializeMatrices()
#     354         # starting point
#     355         c_current = zeros(self.__dim, float64)
#
# ~\Desktop\qns3vm.py in __initializeMatrices(self)
#     380             for l in self.__L_l:
#     381                 x.append(l)
# --> 382             self.__YL = mat(x, dtype=np.float64)
#     383             self.__YL = self.__YL.transpose()
#     384             # Initialize kernel matrices
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in asmatrix(data, dtype)
#      69
#      70     """
# ---> 71     return matrix(data, dtype=dtype, copy=False)
#      72
#      73
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __new__(subtype, data, dtype, copy)
#     121                       'numpy-for-matlab-users.html). '
#     122                       'Please adjust your code to use regular ndarray.',
# --> 123                       PendingDeprecationWarning, stacklevel=2)
#     124         if isinstance(data, matrix):
#     125             dtype2 = data.dtype
#
# PendingDeprecationWarning: the matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
